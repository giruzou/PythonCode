# %%
from IPython.display import display

from __future__ import print_function

import ipywidgets as widgets
from bokeh.io import output_notebook, push_notebook
from bokeh.plotting import figure, show

d = widgets.Dropdown(options=['red', 'green', 'blue'], value='blue')


def on_value_change(change):
    r.glyph.fill_color = change['new']
    push_notebook(handle=t)
def f(x):
    print(x)

d.observe(on_value_change, names='value')

p = figure(width=250, height=250)
r = p.circle(1, 1, size=20, line_color=None)

output_notebook()

display(d)
t = show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="aa1a80d0-5ef3-493f-8df1-6f0bd67595e0">Loading BokehJS ...</span>
#     </div>
# Widget Javascript not detected.  It may not be installed or enabled properly.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5ec8ac7f-6598-49e4-a1ee-2826e283550c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("5ec8ac7f-6598-49e4-a1ee-2826e283550c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("c80a7eaf-0fab-492d-964c-7b984001f5c9", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5ec8ac7f-6598-49e4-a1ee-2826e283550c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5ec8ac7f-6598-49e4-a1ee-2826e283550c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1dee3770-21fa-4f20-bd54-85f644e7743a":{"roots":{"references":[{"attributes":{"plot":{"id":"fe5f6856-2223-4179-9855-fc22f9795d92","subtype":"Figure","type":"Plot"},"ticker":{"id":"28f48849-b6e1-4ef2-a055-75c395c39310","type":"BasicTicker"}},"id":"ab08ff4a-35e8-4b53-9c2c-eb0c001e4e64","type":"Grid"},{"attributes":{"plot":{"id":"fe5f6856-2223-4179-9855-fc22f9795d92","subtype":"Figure","type":"Plot"}},"id":"1b270f12-d612-4c64-ba73-74582bdd0b00","type":"PanTool"},{"attributes":{"plot":{"id":"fe5f6856-2223-4179-9855-fc22f9795d92","subtype":"Figure","type":"Plot"}},"id":"30d2c636-6ae3-4fc2-9b49-4f0c92a190ca","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"860073ec-2a7b-4b65-a905-1d855f2cabb9","type":"BoxAnnotation"},{"attributes":{},"id":"ec5a0d1f-7c6b-424e-9d19-04447b630fb7","type":"ToolEvents"},{"attributes":{"callback":null},"id":"fd3c1203-6344-4776-a4a6-b07f01e01985","type":"DataRange1d"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":null},"size":{"units":"screen","value":20},"x":{"value":1},"y":{"value":1}},"id":"92eaa5a1-4363-4539-bd09-653956535a19","type":"Circle"},{"attributes":{},"id":"6670a83b-748f-4634-ba3d-63729e3aedda","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"860073ec-2a7b-4b65-a905-1d855f2cabb9","type":"BoxAnnotation"},"plot":{"id":"fe5f6856-2223-4179-9855-fc22f9795d92","subtype":"Figure","type":"Plot"}},"id":"86430e6e-e578-462c-9beb-729e7e883d7a","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":""},"id":"e67417ee-76bb-45c0-b500-fe571ef5d239","type":"Title"},{"attributes":{"plot":{"id":"fe5f6856-2223-4179-9855-fc22f9795d92","subtype":"Figure","type":"Plot"}},"id":"d8adbabf-84fd-4dbb-9021-a105e87b15e4","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"fe5f6856-2223-4179-9855-fc22f9795d92","subtype":"Figure","type":"Plot"},"ticker":{"id":"21bb558c-45c5-4752-a88e-4beda75c46c1","type":"BasicTicker"}},"id":"7862c599-3207-4646-b6f5-24deb0027c8b","type":"Grid"},{"attributes":{"below":[{"id":"afb5df0a-5bbb-4305-8328-e12ba4213dca","type":"LinearAxis"}],"left":[{"id":"65b176b7-af8a-4828-ba80-b902214f6aee","type":"LinearAxis"}],"plot_height":250,"plot_width":250,"renderers":[{"id":"afb5df0a-5bbb-4305-8328-e12ba4213dca","type":"LinearAxis"},{"id":"ab08ff4a-35e8-4b53-9c2c-eb0c001e4e64","type":"Grid"},{"id":"65b176b7-af8a-4828-ba80-b902214f6aee","type":"LinearAxis"},{"id":"7862c599-3207-4646-b6f5-24deb0027c8b","type":"Grid"},{"id":"860073ec-2a7b-4b65-a905-1d855f2cabb9","type":"BoxAnnotation"},{"id":"33de2c8a-94e2-440c-a345-b79440e1b754","type":"GlyphRenderer"}],"title":{"id":"e67417ee-76bb-45c0-b500-fe571ef5d239","type":"Title"},"tool_events":{"id":"ec5a0d1f-7c6b-424e-9d19-04447b630fb7","type":"ToolEvents"},"toolbar":{"id":"676d5ce1-18fd-47e1-bd46-9a73a4490198","type":"Toolbar"},"x_range":{"id":"fd3c1203-6344-4776-a4a6-b07f01e01985","type":"DataRange1d"},"y_range":{"id":"c2c9902c-8c97-4240-a4be-0eb68a6f1f11","type":"DataRange1d"}},"id":"fe5f6856-2223-4179-9855-fc22f9795d92","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"f69c7b79-2d7d-4d9c-af37-4899e383ade8","type":"ColumnDataSource"},"glyph":{"id":"92eaa5a1-4363-4539-bd09-653956535a19","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"c9f539ac-51e8-4321-b70c-c9bdf796f517","type":"Circle"},"selection_glyph":null},"id":"33de2c8a-94e2-440c-a345-b79440e1b754","type":"GlyphRenderer"},{"attributes":{},"id":"8ef75369-b2a2-4344-b6ad-0bd7f9596d48","type":"BasicTickFormatter"},{"attributes":{},"id":"21bb558c-45c5-4752-a88e-4beda75c46c1","type":"BasicTicker"},{"attributes":{"plot":{"id":"fe5f6856-2223-4179-9855-fc22f9795d92","subtype":"Figure","type":"Plot"}},"id":"ec57420f-9 ...

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
def f(x):
    print(x)

interact(f, x=(-10, 10, 2));
# Out:
# 0
