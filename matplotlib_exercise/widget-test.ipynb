# %%
from IPython.display import display

from __future__ import print_function

import ipywidgets as widgets
from bokeh.io import output_notebook, push_notebook
from bokeh.plotting import figure, show

d = widgets.Dropdown(options=['red', 'green', 'blue'], value='blue')


def on_value_change(change):
    r.glyph.fill_color = change['new']
    push_notebook(handle=t)
def f(x):
    print(x)

d.observe(on_value_change, names='value')

p = figure(width=250, height=250)
r = p.circle(1, 1, size=20, line_color=None)

output_notebook()

display(d)
t = show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f80c31a4-eab4-4b5d-b00a-63520e58ca57">Loading BokehJS ...</span>
#     </div>
# Widget Javascript not detected.  It may not be installed or enabled properly.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c8c0588c-e135-49a9-ac6b-a008dea52e98"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c8c0588c-e135-49a9-ac6b-a008dea52e98").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("78deba42-b6ff-4b7c-83b4-98d39710589f", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c8c0588c-e135-49a9-ac6b-a008dea52e98");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c8c0588c-e135-49a9-ac6b-a008dea52e98' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"00e38736-1137-41b7-ae8c-2b4111b7958d":{"roots":{"references":[{"attributes":{"formatter":{"id":"bc91ab9c-238f-497b-a170-f65885c2abe4","type":"BasicTickFormatter"},"plot":{"id":"d187ceb3-ffe5-4d29-bb37-bc35ce9f9599","subtype":"Figure","type":"Plot"},"ticker":{"id":"e9f22865-8afb-401b-a7f0-63ea872ed824","type":"BasicTicker"}},"id":"df8f95bb-5582-4554-9eab-35c36c6b36d4","type":"LinearAxis"},{"attributes":{"callback":null},"id":"14e2e9c9-1faf-4a27-958a-96522b7ceed5","type":"DataRange1d"},{"attributes":{"data_source":{"id":"43d7cd91-fb9f-4cf4-94c7-be14a3603b71","type":"ColumnDataSource"},"glyph":{"id":"f53bac68-ed81-411d-b8b8-250557f5deb6","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"096ab12c-261b-4e17-80c9-292cd330ae76","type":"Circle"},"selection_glyph":null},"id":"f319e7d3-39e4-4726-a90b-d21fd1f9adf7","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"d187ceb3-ffe5-4d29-bb37-bc35ce9f9599","subtype":"Figure","type":"Plot"}},"id":"7f5f6897-1aca-4e70-be9b-912526083d40","type":"ResetTool"},{"attributes":{"formatter":{"id":"5f5585f3-e49c-4670-b463-307f97af9837","type":"BasicTickFormatter"},"plot":{"id":"d187ceb3-ffe5-4d29-bb37-bc35ce9f9599","subtype":"Figure","type":"Plot"},"ticker":{"id":"c6d1f583-ec4a-4725-9392-42247780db86","type":"BasicTicker"}},"id":"9c9536c8-acf1-4336-8499-506c27b8b167","type":"LinearAxis"},{"attributes":{},"id":"c6d1f583-ec4a-4725-9392-42247780db86","type":"BasicTicker"},{"attributes":{"plot":{"id":"d187ceb3-ffe5-4d29-bb37-bc35ce9f9599","subtype":"Figure","type":"Plot"}},"id":"6beb8784-ddfb-4c3b-ad3b-3007d664e4f4","type":"PanTool"},{"attributes":{"overlay":{"id":"127a5722-8355-4132-928e-69e80eb7bbb5","type":"BoxAnnotation"},"plot":{"id":"d187ceb3-ffe5-4d29-bb37-bc35ce9f9599","subtype":"Figure","type":"Plot"}},"id":"46bb0ebc-c4e0-486b-b2b6-42f38523ec73","type":"BoxZoomTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":null},"size":{"units":"screen","value":20},"x":{"value":1},"y":{"value":1}},"id":"f53bac68-ed81-411d-b8b8-250557f5deb6","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"d187ceb3-ffe5-4d29-bb37-bc35ce9f9599","subtype":"Figure","type":"Plot"},"ticker":{"id":"e9f22865-8afb-401b-a7f0-63ea872ed824","type":"BasicTicker"}},"id":"a5966944-9b0a-45f5-be56-5057cb7475a2","type":"Grid"},{"attributes":{"plot":{"id":"d187ceb3-ffe5-4d29-bb37-bc35ce9f9599","subtype":"Figure","type":"Plot"}},"id":"8a7f81d3-16f8-4882-9317-2c62c5d8ed66","type":"WheelZoomTool"},{"attributes":{},"id":"e9f22865-8afb-401b-a7f0-63ea872ed824","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"f1b151d6-2a76-49b9-8e6f-15d1feff7f9e","type":"Title"},{"attributes":{},"id":"03b8260a-aa12-41ad-8e7b-19bcda701574","type":"ToolEvents"},{"attributes":{"below":[{"id":"9c9536c8-acf1-4336-8499-506c27b8b167","type":"LinearAxis"}],"left":[{"id":"df8f95bb-5582-4554-9eab-35c36c6b36d4","type":"LinearAxis"}],"plot_height":250,"plot_width":250,"renderers":[{"id":"9c9536c8-acf1-4336-8499-506c27b8b167","type":"LinearAxis"},{"id":"5be6b062-7fab-413e-8df4-524cf142c057","type":"Grid"},{"id":"df8f95bb-5582-4554-9eab-35c36c6b36d4","type":"LinearAxis"},{"id":"a5966944-9b0a-45f5-be56-5057cb7475a2","type":"Grid"},{"id":"127a5722-8355-4132-928e-69e80eb7bbb5","type":"BoxAnnotation"},{"id":"f319e7d3-39e4-4726-a90b-d21fd1f9adf7","type":"GlyphRenderer"}],"title":{"id":"f1b151d6-2a76-49b9-8e6f-15d1feff7f9e","type":"Title"},"tool_events":{"id":"03b8260a-aa12-41ad-8e7b-19bcda701574","type":"ToolEvents"},"toolbar":{"id":"75bc50c5-e67f-486e-a002-0370e5dea214","type":"Toolbar"},"x_range":{"id":"14e2e9c9-1faf-4a27-958a-96522b7ceed5","type":"DataRange1d"},"y_range":{"id":"81db57f1-9724-457f-81ef-0f6f07dc19d2","type":"DataRange1d"}},"id":"d187ceb3-ffe5-4d29-bb37-bc35ce9f9599","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"5f5585f3-e49c-4670-b463-307f97af9837","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha ...

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
def f(x):
    print(x)

interact(f, x=(-10, 10, 2));
# Out:
# 0

# %%
# %matplotlib notebook

from __future__ import print_function
"""
Do a mouseclick somewhere, move the mouse to some destination, release
the button.  This class gives click- and release-events and also draws
a line or a box from the click-point to the actual mouseposition
(within the same axes) until the button is released.  Within the
method 'self.ignore()' it is checked whether the button from eventpress
and eventrelease are the same.

"""
from matplotlib.widgets import RectangleSelector
import numpy as np
import matplotlib.pyplot as plt


def line_select_callback(eclick, erelease):
    'eclick and erelease are the press and release events'
    x1, y1 = eclick.xdata, eclick.ydata
    x2, y2 = erelease.xdata, erelease.ydata
    print("(%3.2f, %3.2f) --> (%3.2f, %3.2f)" % (x1, y1, x2, y2))
    print(" The button you used were: %s %s" % (eclick.button, erelease.button))


def toggle_selector(event):
    print(' Key pressed.')
    if event.key in ['Q', 'q'] and toggle_selector.RS.active:
        print(' RectangleSelector deactivated.')
        toggle_selector.RS.set_active(False)
    if event.key in ['A', 'a'] and not toggle_selector.RS.active:
        print(' RectangleSelector activated.')
        toggle_selector.RS.set_active(True)


fig, current_ax = plt.subplots()                 # make a new plotting range
N = 100000                                       # If N is large one can see
x = np.linspace(0.0, 10.0, N)                    # improvement by use blitting!

plt.plot(x, +np.sin(.2*np.pi*x), lw=3.5, c='b', alpha=.7)  # plot something
plt.plot(x, +np.cos(.2*np.pi*x), lw=3.5, c='r', alpha=.5)
plt.plot(x, -np.sin(.2*np.pi*x), lw=3.5, c='g', alpha=.3)

print("\n      click  -->  release")

# drawtype is 'box' or 'line' or 'none'
toggle_selector.RS = RectangleSelector(current_ax, line_select_callback,
                                       drawtype='box', useblit=True,
                                       button=[1, 3],  # don't use middle button
                                       minspanx=5, minspany=5,
                                       spancoords='pixels',
                                       interactive=True)
plt.connect('key_press_event', toggle_selector)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
#       click  -->  release
